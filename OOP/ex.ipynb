# %%
class Student:
    def __init__(self, name, id, major):
        self.name = name
        self.id = id
        self.major = major
    def print_info(self):
        print(f"Name: {self.name}, Id: {self.id}, Major: {self.major}")

s1 = Student("An", "001", "CS")
s2 = Student("Binh", "002", "DS")
s3 = Student("Chung", "003", "AI")

s1.print_info()
s2.print_info()
# Out:
# Name: An, Id: 001, Major: CS
# Name: Binh, Id: 002, Major: DS

# %%
import math
class Circle: 
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return math.pi*self.radius**2
    def perimeter(self):
        return 2*math.pi*self.radius

c1 = Circle(2)
print(f"Radius is 2: area = {c1.area()}, perimeter = {c1.perimeter()}")
# Out:
# Radius is 2: area = 12.566370614359172, perimeter = 12.566370614359172

# %%
class Book:
    def __init__(self, title, author, price):
        self.title = title
        self.author = author
        self.price = price
    def discount(self):
        self.price = self.price*0.9
        return self.price
    def display(self):
        print(f"Title: {self.title}, Author: {self.author}, Price: {self.price}")

b1 = Book("Programming for beginners", "PI", 1000)
b1.display()
b1.discount()
b1.display()
# Out:
# Title: Programming for beginners, Author: PI, Price: 1000
# Title: Programming for beginners, Author: PI, Price: 900.0

# %%
class Calculator:
    def add(self, a, b):
        return a + b
    def subtract(self, a, b):
        return a - b
    def multiply(self, a, b):
        return a*b
    def divide(self, a, b):
        if b == 0:
            return "Can not devided to zere"
        return a/b
a = 4
b = 2
c1 = Calculator()
c1. add(a, b)
c1.multiply(a,b)
# Out:
# 8

# %%
class Employee:
    company = "TechCorp"
    def __init__(self, name, salary):
        self.name = name
        self.
